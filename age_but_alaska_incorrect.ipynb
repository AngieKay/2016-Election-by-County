# %% [markdown]
# This data came in with only 3 counties for Alaska. Pretty much can't use it.

# %%
import pandas

# %%
import pandas as pd
pd.set_option("max_columns", None)
pd.set_option('max_rows', None)

# %%
df = pd.read_csv('ACS_age_info.csv')

# %%
df.head()
# Out:
#                id     Geographic Area Name  \
# 0  0500000US01003  Baldwin County, Alabama
# 1  0500000US01015  Calhoun County, Alabama
# 2  0500000US01043  Cullman County, Alabama
# 3  0500000US01049   DeKalb County, Alabama
# 4  0500000US01051   Elmore County, Alabama
#
#    Estimate!!SEX AND AGE!!Total population  \
# 0                                   208563
# 1                                   114611
# 2                                    82471
# 3                                    70900
# 4                                    81799
#
#    Estimate!!SEX AND AGE!!Total population!!Male  \
# 0                                         100902
# 1                                          55491
# 2                                          40699
# 3                                          34509
# 4                                          39956
#
#    Estimate!!SEX AND AGE!!Total population!!Female  \
# 0                                           107661
# ...

# %%
df.columns = df.columns.str.strip('Estimate!!SEX AND AGE!!')

# %%
df.columns.str.strip('year')
# Out:
# Index(['d', 'ographic A', 'Total population', 'Total population!!Mal',
#        'Total population!!Femal', 'Under 5 ', '5 to 9 ', '10 to 14 ',
#        '15 to 19 ', '20 to 24 ', '25 to 34 ', '35 to 44 ', '45 to 54 ',
#        '55 to 59 ', '60 to 64 ', '65 to 74 ', '75 to 84 ', '85 years and ov',
#        'Median age (years)', '18 years and ov', '21 years and ov',
#        '62 years and ov', '65 years and ov', '18 years and over.1',
#        '18 years and over!!Mal', '18 years and over!!Femal',
#        '65 years and over.1', '65 years and over!!Mal',
#        '65 years and over!!Femal'],
#       dtype='object')

# %%
df.columns = ['id', 'county_state', 'total_pop', 'total_pop_male', 'total_pop_female', 'under_5', '5_to_9', '10_to_14', '15_to_19', '20_to_24', '25_to_34', '35_to_44', '45_to_54', '55_to_59', '60_to_64', '65_to_74', '75_to_84', '85_and_over', 'median_age', '18_and_over', '21_and_over', '62_and_over', '65_and_over', '18_and_over_total', '18_and_over_male', '18_and_over_female', '65_and_over_total', '65_and_over_male', '65_and_over_female']

# %%
df = df.drop(['18_and_over_total'], axis = 1)
df = df.drop(['65_and_over_total'], axis = 1)

# %%
df.columns
# Out:
# Index(['id', 'county_state', 'total_pop', 'total_pop_male', 'total_pop_female',
#        'under_5', '5_to_9', '10_to_14', '15_to_19', '20_to_24', '25_to_34',
#        '35_to_44', '45_to_54', '55_to_59', '60_to_64', '65_to_74', '75_to_84',
#        '85_and_over', 'median_age', '18_and_over', '21_and_over',
#        '62_and_over', '65_and_over', '18_and_over_male', '18_and_over_female',
#        '65_and_over_male', '65_and_over_female'],
#       dtype='object')

# %%
df.head()
# Out:
#                id             county_state  total_pop  total_pop_male  \
# 0  0500000US01003  Baldwin County, Alabama     208563          100902
# 1  0500000US01015  Calhoun County, Alabama     114611           55491
# 2  0500000US01043  Cullman County, Alabama      82471           40699
# 3  0500000US01049   DeKalb County, Alabama      70900           34509
# 4  0500000US01051   Elmore County, Alabama      81799           39956
#
#    total_pop_female  under_5  5_to_9  10_to_14  15_to_19  20_to_24  ...  \
# 0            107661    10938   13516     13190     13478     10454  ...
# 1             59120     6073    7297      6896      8122      8005  ...
# 2             41772     4856    4650      5206      5069      5221  ...
# 3             36391     3951    4220      5518      5587      3397  ...
# 4             41843     4284    5826      5481      4533      5451  ...
#
#    85_and_over  median_age  18_and_over  21_and_over  62_and_over  \
# ...

# %%
df.isna().sum()
# Out:
# id                    0
# county_state          0
# total_pop             0
# total_pop_male        0
# total_pop_female      0
# under_5               0
# 5_to_9                0
# 10_to_14              0
# 15_to_19              0
# 20_to_24              0
# 25_to_34              0
# 35_to_44              0
# 45_to_54              0
# 55_to_59              0
# 60_to_64              0
# 65_to_74              0
# 75_to_84              0
# 85_and_over           0
# median_age            0
# 18_and_over           0
# 21_and_over           0
# 62_and_over           0
# 65_and_over           0
# 18_and_over_male      0
# 18_and_over_female    0
# 65_and_over_male      0
# 65_and_over_female    0
# dtype: int64

# %%
df[['county', 'state']] = df['county_state'].str.split(',', expand=True)

# %%
df.drop('county_state', axis = 1, inplace = True)

# %%
df['county'] = df['county'].str.replace('(Borough|Area|Census|Municipality|and|City|Municipali|County)', '')
# Out:
# <ipython-input-16-0887acb02804>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['county'] = df['county'].str.replace('(Borough|Area|Census|Municipality|and|City|Municipali|County)', '')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 831 entries, 0 to 830
# Data columns (total 28 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  831 non-null    object
#  1   total_pop           831 non-null    int64
#  2   total_pop_male      831 non-null    int64
#  3   total_pop_female    831 non-null    int64
#  4   under_5             831 non-null    int64
#  5   5_to_9              831 non-null    int64
#  6   10_to_14            831 non-null    int64
#  7   15_to_19            831 non-null    int64
#  8   20_to_24            831 non-null    int64
#  9   25_to_34            831 non-null    int64
#  10  35_to_44            831 non-null    int64
#  11  45_to_54            831 non-null    int64
#  12  55_to_59            831 non-null    int64
#  13  60_to_64            831 non-null    int64
#  14  65_to_74            831 non-null    int64
#  15  75_to_84            831 non-null    int64
# ...

# %%
df
# Out:
#                  id  total_pop  total_pop_male  total_pop_female  under_5  \
# 0    0500000US01003     208563          100902            107661    10938
# 1    0500000US01015     114611           55491             59120     6073
# 2    0500000US01043      82471           40699             41772     4856
# 3    0500000US01049      70900           34509             36391     3951
# 4    0500000US01051      81799           39956             41843     4284
# 5    0500000US01055     102564           49861             52703     5505
# 6    0500000US01069     104056           50015             54041     6221
# 7    0500000US01073     659521          310913            348608    42831
# 8    0500000US01077      92318           45121             47197     4944
# 9    0500000US01081     158991           79257             79734     9170
# 10   0500000US01083      92753           47635             45118     4701
# 11   0500000US01089     356967          174569            182398    20121
# ...

# %%
df.state.value_counts()
# Out:
#  Texas                   53
#  Florida                 41
#  California              40
#  Pennsylvania            40
#  North Carolina          40
#  Ohio                    39
#  New York                39
#  Georgia                 36
#  Virginia                30
#  Michigan                29
#  Indiana                 25
#  Illinois                23
#  Wisconsin               23
#  New Jersey              21
#  Alabama                 21
#  South Carolina          21
#  Tennessee               20
#  Washington              19
#  Louisiana               17
#  Missouri                17
#  Maryland                16
#  Oregon                  15
#  Minnesota               14
#  Kentucky                13
#  Colorado                12
#  Massachusetts           12
#  Oklahoma                11
#  Puerto Rico             11
#  Arkansas                11
#  Arizona                 10
#  Iowa                    10
#  New Mexico              10
#  Mississippi             10
# ...
