# %% [markdown]
# Import tools.

# %%
import pandas as pd
from pickle import load
from pickle import dump
import numpy as np
pd.set_option("max_rows", None)
pd.set_option("max_columns", None)

# %% [markdown]
# The goal of this project is to build a model that can predict the winner of presidential elections by county. Data was gathered from several different sources and then preprocessed and joined together.
#
# Data:
# 2016 and 2012 election results: https://data.world/garyhoov/2016-pres-election-by-county
# Alaska 2016 and 2012 election results: https://www.thecinyc.com/
# Additional Alaska information: https://en.wikipedia.org/wiki/List_of_boroughs_and_census_areas_in_Alaska
# Race: https://data.census.gov/cedsci/table?q=county%20population&tid=DECENNIALPL2020.P1
# Income: https://data.census.gov/cedsci/all?q=county%20population

# %% [markdown]
# ## First Dataset: RESULTS

# %% [markdown]
# This dataset includes 2016 Presidential election results by county, 2012 presidential election results by county, county density, county type, and land area. It does not include Alaska. Alaska information can be found in the next section of this notebook.
# Data: https://data.world/garyhoov/2016-pres-election-by-county

# %% [markdown]
# Open dataset.

# %%
results = pd.read_csv('data/2016 Presidential Election Analysis.csv')

# %%
results.head()
# Out:
#   State Code     County Name  County Population  Clinton or Trump State  \
# 0         AL  Autauga County             55,347                   Trump
# 1         AL  Baldwin County            203,709                   Trump
# 2         AL  Barbour County             26,489                   Trump
# 3         AL     Bibb County             22,583                   Trump
# 4         AL   Blount County             57,673                   Trump
#
#    Clinton     Trump     Total  % Clinton % Trump  Vote Difference C-T   \
# 0    5,908    18,110    24,661     23.96%  73.44%              (12,202)
# 1   18,409    72,780    94,090     19.57%  77.35%              (54,371)
# 2    4,848     5,431    10,390     46.66%  52.27%                 (583)
# 3    1,874     6,733     8,748     21.42%  76.97%               (4,859)
# 4    2,150    22,808    25,384      8.47%  89.85%              (20,658)
#
#    Vote Difference T-C  Percent Difference C-T Percent Difference T-C  \
# 0               12,202                 -49.48%                 49.48%
# 1               54,371                 -57.79%                 57.79%
# 2                  583                  -5.61%                  5.61%
# 3                4,859                 -55.54%                 55.54%
# 4               20,658                 -81.38%                 81.38%
#
#      Obama    Romney   2012 Total Votes  % Obama % Romney  \
# 0    6,354    17,366             23,909   26.58%   72.63%
# 1   18,329    65,772             84,988   21.57%   77.39%
# 2    5,873     5,539             11,459   51.25%   48.34%
# 3    2,200     6,131              8,391   26.22%   73.07%
# 4    2,961    20,741             23,980   12.35%   86.49%
#
#    Vote Difference O-R  % Difference O-R Clinton B(W) Obama Trump B(W) Romney  \
# 0              (11,012)          -46.06%              (446)              744
# 1              (47,443)          -55.82%                80             7,008
# 2                  334             2.91%            (1,025)             (108)
# 3               (3,931)          -46.85%              (326)              602
# 4              (17,780)          -74.15%              (811)            2,067
#
#   Clinton % B(W) Obama Trump % B(W) Romney  2010 Land Area  Density  \
# 0               -2.62%               0.80%             594       93
# 1               -2.00%              -0.04%            1590      128
# 2               -4.59%               3.93%             885       30
# 3               -4.80%               3.90%             623       36
# 4               -3.88%               3.36%             645       89
#
#   Combined FIPS Code ANSI Code  State FIPS Code  County FIPS Code  CBSA Code  \
# 0               1001     01001              1.0               1.0    33860.0
# 1               1003     01003              1.0               3.0    19300.0
# 2               1005     01005              1.0               5.0    21640.0
# 3               1007     01007              1.0               7.0    13820.0
# 4               1009     01009              1.0               9.0    13820.0
#
#    CSA Code                 CBSA Title CBSA Population  \
# 0       NaN             Montgomery, AL         373,792
# 1     380.0  Daphne-Fairhope-Foley, AL         203,709
# 2       NaN             Eufaula, AL-GA             NaN
# 3     142.0      Birmingham-Hoover, AL       1,145,647
# 4     142.0      Birmingham-Hoover, AL       1,145,647
#
#   Metropolitan/Micropolitan Statistical Area                        CSA Title  \
# 0              Metropolitan Statistical Area                              NaN
# 1              Metropolitan Statistical Area       Mobile-Daphne-Fairhope, AL
# 2              Micropolitan Statistical Area                              NaN
# 3              Metropolitan Statistical Area  Birmingham-Hoover-Talladega, AL
# 4              Metropolitan Statistical Area  Birmingham-Hoover-Talladega, AL
#
#   Metropolitan Division Title  Metropolitan Division Code  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#   Central/Outlying County
# 0                 Central
# 1                 Central
# 2                 Central
# 3                Outlying
# 4                Outlying

# %% [markdown]
# Only keep helpful columns. Keep Clinton and Trump total votes until target is established.

# %%
results = results.iloc[:, [0, 1, 4, 5, 6, 13, 14, 15, 24, 25, 38]]

# %%
results.head()
# Out:
#   State Code     County Name  Clinton     Trump     Total     Obama   \
# 0         AL  Autauga County    5,908    18,110    24,661     6,354
# 1         AL  Baldwin County   18,409    72,780    94,090    18,329
# 2         AL  Barbour County    4,848     5,431    10,390     5,873
# 3         AL     Bibb County    1,874     6,733     8,748     2,200
# 4         AL   Blount County    2,150    22,808    25,384     2,961
#
#     Romney   2012 Total Votes   2010 Land Area  Density  \
# 0   17,366             23,909              594       93
# 1   65,772             84,988             1590      128
# 2    5,539             11,459              885       30
# 3    6,131              8,391              623       36
# 4   20,741             23,980              645       89
#
#   Central/Outlying County
# 0                 Central
# 1                 Central
# 2                 Central
# 3                Outlying
# 4                Outlying

# %% [markdown]
# Remove punctuation from column names and values.

# %%
results.columns = results.columns.str.strip().str.replace('[^\w\s]', '')
# Out:
# <ipython-input-116-12a2c89aa82b>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   results.columns = results.columns.str.strip().str.replace('[^\w\s]', '')

# %%
def remove_punctuation(x):
    try:
        x = x.str.replace('[^\w\s]','')
    except:
        pass
    return x

# %%
results = results.apply(remove_punctuation)
# Out:
# <ipython-input-117-fabae1a16f96>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   x = x.str.replace('[^\w\s]','')

# %%
results.head()
# Out:
#   State Code     County Name  Clinton    Trump    Total    Obama   Romney  \
# 0         AL  Autauga County    5908    18110    24661     6354    17366
# 1         AL  Baldwin County   18409    72780    94090    18329    65772
# 2         AL  Barbour County    4848     5431    10390     5873     5539
# 3         AL     Bibb County    1874     6733     8748     2200     6131
# 4         AL   Blount County    2150    22808    25384     2961    20741
#
#   2012 Total Votes  2010 Land Area  Density CentralOutlying County
# 0           23909              594       93                Central
# 1           84988             1590      128                Central
# 2           11459              885       30                Central
# 3            8391              623       36               Outlying
# 4           23980              645       89               Outlying

# %% [markdown]
# Lengthen state names.

# %%
us_state_abbrev = {
    'AL': 'Alabama',
    'AK': 'Alaska',
    'AZ': 'Arizona',
    'AR': 'Arkansas',
    'CA': 'California',
    'CO': 'Colorado',
    'CT': 'Connecticut',
    'DE': 'Delaware',
    'FL': 'Florida',
    'GA': 'Georgia',
    'HI': 'Hawaii',
    'ID': 'Idaho',
    'IL': 'Illinois',
    'IN': 'Indiana',
    'IA': 'Iowa',
    'KS': 'Kansas',
    'KY': 'Kentucky',
    'LA': 'Louisiana',
    'ME': 'Maine',
    'MD': 'Maryland',
    'MA': 'Massachusetts',
    'MI': 'Michigan',
    'MN': 'Minnesota',
    'MS': 'Mississippi',
    'MO': 'Missouri',
    'MT': 'Montana',
    'NE': 'Nebraska',
    'NV': 'Nevada',
    'NH': 'New Hampshire',
    'NJ': 'New Jersey',
    'NM': 'New Mexico',
    'NY': 'New York',
    'NC': 'North Carolina',
    'ND': 'North Dakota',
    'OH': 'Ohio',
    'OK': 'Oklahoma',
    'OR': 'Oregon',
    'PA': 'Pennsylvania',
    'RI': 'Rhode Island',
    'SC': 'South Carolina',
    'SD': 'South Dakota',
    'TN': 'Tennessee',
    'TX': 'Texas',
    'UT': 'Utah',
    'VT': 'Vermont',
    'VA': 'Virginia',
    'WA': 'Washington',
    'WV': 'West Virginia',
    'WI': 'Wisconsin',
    'WY': 'Wyoming',
}

# %%
results['State Code'] = results['State Code'].map(us_state_abbrev)

# %% [markdown]
# Rename columns.

# %%
results.rename(columns = {'Total': '2016_total_votes', '2012 Total Votes':'2012_total_votes', 'State Code': 'State', 'County Name': 'County', 'CentralOutlying County': 'central_outlying', '2010 Land Area': '2010_land_area'}, inplace = True)

# %% [markdown]
# If state is missing, fill with county name. Pretty sure this only applies to DC.

# %%
results['State'] = results['State'].fillna(results['County'])

# %% [markdown]
# Alaska is not broken down by county in this dataset. Dropping all Alaska info and pulling in results and info from another source.

# %%
results.drop(results.loc[results['State'].str.contains('Alaska', case=False)].index, inplace = True)

# %% [markdown]
# Simplify long string to easier to read string.

# %%
results.replace('Not Metro or Micro Presumed Rural', 'Rural', inplace = True)

# %% [markdown]
# Change datatypes to numeric where necessary.

# %%
results.iloc[:, 2:9] = results.iloc[:, 2:9].apply(pd.to_numeric)

# %%
results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3112 entries, 0 to 3112
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State             3112 non-null   object
#  1   County            3112 non-null   object
#  2   Clinton           3112 non-null   int64
#  3   Trump             3112 non-null   int64
#  4   2016_total_votes  3112 non-null   int64
#  5   Obama             3112 non-null   int64
#  6   Romney            3112 non-null   int64
#  7   2012_total_votes  3112 non-null   int64
#  8   2010_land_area    3112 non-null   int64
#  9   Density           3112 non-null   int64
#  10  central_outlying  3112 non-null   object
# dtypes: int64(8), object(3)
# memory usage: 291.8+ KB

# %% [markdown]
# Create new column indicating who won the county. To be used as target for modeling.

# %%
conditions = [(results['Clinton'] < results['Trump']), (results['Clinton'] > results['Trump'])]
choices = ['Trump', 'Clinton']
results['Target'] = np.select(conditions, choices, default = np.nan)

# %% [markdown]
# Drop Clinton and Trump individual columns.

# %%
results = results.drop(results.iloc[:, 2:4], axis = 1)

# %%
results.head()
# Out:
#      State          County  2016_total_votes  Obama  Romney  2012_total_votes  \
# 0  Alabama  Autauga County             24661   6354   17366             23909
# 1  Alabama  Baldwin County             94090  18329   65772             84988
# 2  Alabama  Barbour County             10390   5873    5539             11459
# 3  Alabama     Bibb County              8748   2200    6131              8391
# 4  Alabama   Blount County             25384   2961   20741             23980
#
#    2010_land_area  Density central_outlying Target
# 0             594       93          Central  Trump
# 1            1590      128          Central  Trump
# 2             885       30          Central  Trump
# 3             623       36         Outlying  Trump
# 4             645       89         Outlying  Trump

# %% [markdown]
# ## ALASKA RESULTS

# %% [markdown]
# Data: https://www.thecinyc.com/

# %% [markdown]
# Open Alaska results file.

# %%
alaska_results = pd.read_csv('data/ak_2012_2016.csv')

# %%
alaska_results.head()
# Out:
#            Weighted/Muni  Registered Voters   Clinton, Hillary   \
# 0      Ketchikan Gateway               10512        1966.695802
# 1  Prince of Wales-Hyder                4630        1076.455803
# 2                  Sitka                7218        2110.994000
# 3             Petersburg                2741         569.639406
# 4               Wrangell                1731         270.992898
#
#    Trump, Donald J.   Write-in 60       WtTotal  Unnamed: 6  \
# 0        3451.907138    153.011809  6267.150170         NaN
# 1        1295.125060     91.039696  2830.673904         NaN
# 2        1811.544401    115.703622  4427.915868         NaN
# 3         915.365934     50.796562  1706.007455         NaN
# 4         751.941311     19.081913  1124.152497         NaN
#
#          Weighted/Muni.1               Municode  Registered Voters .1  \
# 0      Ketchikan Gateway              Ketchikan                 10257
# 1  Prince of Wales-Hyder  Prince of Wales-Hyder                  4371
# 2                  Sitka                  Sitka                  7074
# 3             Petersburg             Petersburg                  2648
# 4               Wrangell               Wrangell                  1658
#
#    Total Votes  Johnson/Gray (LIB)  Obama/Biden (DEM)  Romney/Ryan (REP)
# 0  5905.592707          212.061543        2262.784210        3266.635409
# 1  2482.062762           76.243288        1298.248629        1045.101630
# 2  4415.265365          133.089646        2340.002643        1830.694119
# 3  1729.880554           59.211545         776.066018         867.459549
# 4  1143.064441           26.862207         362.631179         738.686288

# %% [markdown]
# Drop unnecessary columns.

# %%
alaska_results = alaska_results.drop(alaska_results.iloc[:, [1, 4, 6, 7, 8, 9, 11]], axis = 1)

# %% [markdown]
# Get rid of commas in column names and rename columns.

# %%
alaska_results.columns = [col.replace(',', '') for col in alaska_results.columns]

# %%
alaska_results = alaska_results.rename(columns = {'Registered Voters': '2016_registered_voters','Weighted/Muni':'County', 'Clinton Hillary':'Clinton', 'Trump Donald J.':'Trump', 'WtTotal':'2016_total_votes', 'Registered Voters .1':'2012_registered_voters', 'Total Votes':'2012_total_votes', 'Obama/Biden (DEM)':'Obama', 'Romney/Ryan (REP)':'Romney'})

# %% [markdown]
# Create target column.

# %%
conditions = [alaska_results.iloc[:, 2] < alaska_results.iloc[:, 3], alaska_results.iloc[:, 2] > alaska_results.iloc[:, 3]]
choices = ['Trump', 'Clinton']
alaska_results['Target'] = np.select(conditions, choices, default = np.nan)

# %%
alaska_results.head()
# Out:
#                   County  Clinton Hillary   Trump Donald J.   \
# 0      Ketchikan Gateway       1966.695802       3451.907138
# 1  Prince of Wales-Hyder       1076.455803       1295.125060
# 2                  Sitka       2110.994000       1811.544401
# 3             Petersburg        569.639406        915.365934
# 4               Wrangell        270.992898        751.941311
#
#    2016_total_votes  2012_total_votes        Obama       Romney Target
# 0       6267.150170       5905.592707  2262.784210  3266.635409  Trump
# 1       2830.673904       2482.062762  1298.248629  1045.101630  Trump
# 2       4427.915868       4415.265365  2340.002643  1830.694119  Trump
# 3       1706.007455       1729.880554   776.066018   867.459549  Trump
# 4       1124.152497       1143.064441   362.631179   738.686288  Trump

# %%
alaska_results = alaska_results.drop(alaska_results.iloc[:, [1, 2]], axis = 1)

# %% [markdown]
# Row 29 is a summed column of all counties. Dropping.

# %%
alaska_results.drop(alaska_results.index[29], inplace = True)

# %% [markdown]
# Wade Hampton county was renamed Kusilvak.

# %%
alaska_results = alaska_results.replace({'Wade Hampton': 'Kusilvak'}, regex = True)

# %% [markdown]
# Add state column and sort by county.

# %%
alaska_results['State'] = 'Alaska'

# %%
alaska_results = alaska_results.sort_values(by = 'County')

# %%
alaska_results.head()
# Out:
#             County  2016_total_votes  2012_total_votes         Obama  \
# 22  Aleutians East        529.293851        549.375577    234.120530
# 24  Aleutians West       1213.502975       1238.761919    777.428504
# 19       Anchorage     130040.329900     125169.133300  54042.760210
# 12          Bethel       4892.232820       4810.611592   3425.621480
# 25     Bristol Bay        453.270615        425.845526    147.147402
#
#           Romney Target   State
# 22    292.395684  Trump  Alaska
# 24    426.573343  Trump  Alaska
# 19  66387.084670  Trump  Alaska
# 12   1151.530057  Trump  Alaska
# 25    251.541638  Trump  Alaska

# %% [markdown]
# ## Additional Alaska Information

# %% [markdown]
# The dataset with Alaska results does not include the additional information that can be found in the results dataset for the rest of the country. Data was pulled from Wikipedia and collected in an excel spreadsheet.
# Data: https://en.wikipedia.org/wiki/List_of_boroughs_and_census_areas_in_Alaska

# %% [markdown]
# Open file.

# %%
missing_columns = pd.read_csv('data/alaska_missing_columns.csv')

# %% [markdown]
# Rename some columns.

# %%
missing_columns.rename(columns = {'Land Area': '2010_land_area', 'Metro/Nonmetro status': 'central_outlying'}, inplace = True)

# %% [markdown]
# Drop strange extra columns.

# %%
missing_columns = missing_columns.drop(missing_columns.iloc[:, 4:6], axis = 1)

# %% [markdown]
# Rename Wade Hampton to Kusilvak.

# %%
missing_columns.replace('Wade Hampton(kusilvak)', 'Kusilvak', inplace = True)

# %% [markdown]
# Change rural to Rural to match other datasets.

# %%
missing_columns.replace('rural', 'Rural', inplace = True)

# %% [markdown]
# Sort for merge.

# %%
missing_columns = missing_columns.sort_values(by = 'Weighted/Muni')

# %%
missing_columns.head()
# Out:
#     Weighted/Muni  Density  2010_land_area central_outlying
# 0  Aleutians East     0.49            6982            Rural
# 1  Aleutians West     1.19            4390            Rural
# 2       Anchorage   170.62            1705          Central
# 3          Bethel     0.46           40570            Rural
# 4     Bristol Bay     1.75             504            Rural

# %% [markdown]
# ## Join Alaska election results with Alaska additional columns.

# %%
alaska_total_results = alaska_results.reset_index(drop=True).merge(missing_columns.reset_index(drop=True), left_index=True, right_index=True)

# %%
alaska_total_results.head()
# Out:
#            County  2016_total_votes  2012_total_votes         Obama  \
# 0  Aleutians East        529.293851        549.375577    234.120530
# 1  Aleutians West       1213.502975       1238.761919    777.428504
# 2       Anchorage     130040.329900     125169.133300  54042.760210
# 3          Bethel       4892.232820       4810.611592   3425.621480
# 4     Bristol Bay        453.270615        425.845526    147.147402
#
#          Romney Target   State   Weighted/Muni  Density  2010_land_area  \
# 0    292.395684  Trump  Alaska  Aleutians East     0.49            6982
# 1    426.573343  Trump  Alaska  Aleutians West     1.19            4390
# 2  66387.084670  Trump  Alaska       Anchorage   170.62            1705
# 3   1151.530057  Trump  Alaska          Bethel     0.46           40570
# 4    251.541638  Trump  Alaska     Bristol Bay     1.75             504
#
#   central_outlying
# 0            Rural
# 1            Rural
# 2          Central
# 3            Rural
# 4            Rural

# %% [markdown]
# Look at county columns side by side to double check.

# %%
alaska_total_results.iloc[:, [0, 7]]
# Out:
#                    County          Weighted/Muni
# 0          Aleutians East         Aleutians East
# 1          Aleutians West         Aleutians West
# 2               Anchorage              Anchorage
# 3                  Bethel                 Bethel
# 4             Bristol Bay            Bristol Bay
# 5                  Denali                 Denali
# 6              Dillingham             Dillingham
# 7    Fairbanks North Star   Fairbanks North Star
# 8                  Haines                 Haines
# 9           Hoonah-Angoon          Hoonah-Angoon
# 10                 Juneau                 Juneau
# 11        Kenai Peninsula        Kenai Peninsula
# 12      Ketchikan Gateway      Ketchikan Gateway
# 13          Kodiak Island          Kodiak Island
# 14               Kusilvak               Kusilvak
# 15     Lake and Peninsula     Lake and Peninsula
# 16      Matanuska-Susitna      Matanuska-Susitna
# 17                   Nome                   Nome
# 18            North Slope            North Slope
# 19       Northwest Arctic       Northwest Arctic
# 20             Petersburg             Petersburg
# 21  Prince of Wales-Hyder  Prince of Wales-Hyder
# 22                  Sitka                  Sitka
# 23                Skagway                Skagway
# 24    Southeast Fairbanks    Southeast Fairbanks
# 25         Valdez-Cordova         Valdez-Cordova
# 26               Wrangell               Wrangell
# 27                Yakutat                Yakutat
# 28          Yukon-Koyukuk          Yukon-Koyukuk

# %% [markdown]
# Drop second county column.

# %%
alaska_total_results.drop('Weighted/Muni', axis = 1, inplace = True)

# %% [markdown]
# ## Join Alaska results with the rest of the country.

# %%
total_results = results.append(alaska_total_results)

# %%
total_results.head()
# Out:
#      State          County  2016_total_votes    Obama   Romney  \
# 0  Alabama  Autauga County           24661.0   6354.0  17366.0
# 1  Alabama  Baldwin County           94090.0  18329.0  65772.0
# 2  Alabama  Barbour County           10390.0   5873.0   5539.0
# 3  Alabama     Bibb County            8748.0   2200.0   6131.0
# 4  Alabama   Blount County           25384.0   2961.0  20741.0
#
#    2012_total_votes  2010_land_area  Density central_outlying Target
# 0           23909.0             594     93.0          Central  Trump
# 1           84988.0            1590    128.0          Central  Trump
# 2           11459.0             885     30.0          Central  Trump
# 3            8391.0             623     36.0         Outlying  Trump
# 4           23980.0             645     89.0         Outlying  Trump

# %%
total_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3141 entries, 0 to 28
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State             3141 non-null   object
#  1   County            3141 non-null   object
#  2   2016_total_votes  3141 non-null   float64
#  3   Obama             3141 non-null   float64
#  4   Romney            3141 non-null   float64
#  5   2012_total_votes  3141 non-null   float64
#  6   2010_land_area    3141 non-null   int64
#  7   Density           3141 non-null   float64
#  8   central_outlying  3141 non-null   object
#  9   Target            3141 non-null   object
# dtypes: float64(5), int64(1), object(4)
# memory usage: 269.9+ KB

# %% [markdown]
# ## Race info from 2010 Census

# %% [markdown]
# Data: https://data.census.gov/cedsci/table?q=county%20population&tid=DECENNIALPL2020.P1

# %%
df_race = pd.read_csv('data/DECENNIALPL2020.P1_data_with_overlays_2021-10-04T202848.csv', error_bad_lines = False, header = None)

# %% [markdown]
# Sort out columns and index.

# %%
df_race.columns = df_race.iloc[1]

# %%
df_race.drop(df_race.index[1], inplace = True)

# %%
 df_race.drop(df_race.index[0], inplace = True)

# %% [markdown]
# Get rid of columns detailing multi-race breakdown but keep total of multi-race population.

# %%
df_race.drop(df_race.iloc[:, 11:73], axis = 1, inplace = True)

# %% [markdown]
# Split county and state into two columns and drop old column.

# %%
df_race[['County', 'State']] = df_race['Geographic Area Name'].str.split(',', expand=True)

# %%
df_race.drop('Geographic Area Name', axis = 1, inplace = True)

# %% [markdown]
# Get rid of punctuation.

# %%
df_race.columns = df_race.columns.str.strip().str.replace('[^\w\s]', '')
# Out:
# <ipython-input-165-3176a88a0be0>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_race.columns = df_race.columns.str.strip().str.replace('[^\w\s]', '')

# %%
def remove_punctuation(x):
    try:
        x = x.str.replace('[^\w\s]','')
    except:
        pass
    return x
df_race = df_race.apply(remove_punctuation)
# Out:
# <ipython-input-166-5daa401cd4a4>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   x = x.str.replace('[^\w\s]','')

# %% [markdown]
# Convert race/population info into floats.

# %%
df_race[df_race.columns[1:-2]] = df_race[df_race.columns[1:-2]].astype(float)

# %% [markdown]
# Chugach and Copper River counties in Alaska were combined between the time of the census and the time of the election.

# %%
chugach = (df_race.loc[df_race['County'] == 'Chugach Census Area'])

# %%
copper_river = (df_race.loc[df_race['County'] == 'Copper River Census Area'])

# %%
old_counties = chugach.append(copper_river)
valdez = pd.DataFrame(old_counties.sum(numeric_only = False, axis = 0)).T
df_race.drop(old_counties.index, axis = 0, inplace= True)
df_race = df_race.append(valdez)

# %%
df_race = df_race.replace({'0500000US020630500000US02066': 'akcombined', 'Chugach Census AreaCopper River Census Area': 'Valdez Cordova'})
df_race['State'] = df_race['State'].str.replace('Alaska Alaska', 'Alaska')

# %% [markdown]
# Drop Puerto Rico because they can not vote in presidential elections.

# %%
pr = df_race.loc[df_race['State'].str.contains('Puerto Rico', case=False)]

# %%
df_race = df_race.drop(pr.index, axis = 0)

# %% [markdown]
# Dropping Kalawoa. It only has 82 residents and is not in other datasets.

# %%
Kalawao = df_race.loc[df_race['County'].str.contains('Kalawao', case=False)]

# %%
df_race = df_race.drop(Kalawao.index, axis = 0)

# %% [markdown]
# Rename annoying columns.

# %%
df_race.rename(columns = {'Total': 'total_pop', 'TotalPopulation of one race': 'total_pop_one_race', 'TotalPopulation of one raceWhite alone':'pop_white', 'TotalPopulation of one raceBlack or African American alone': 'pop_african_american', 'TotalPopulation of one raceAmerican Indian and Alaska Native alone': 'pop_native', 'TotalPopulation of one raceAsian alone': 'pop_asian', 'TotalPopulation of one raceNative Hawaiian and Other Pacific Islander alone': 'pop_islander', 'TotalPopulation of one raceSome Other Race alone': 'pop_other', 'TotalPopulation of two or more races': 'total_pop_two_races'}, inplace = True)

# %% [markdown]
# Sort and reset index for joining.

# %%
df_race = df_race.sort_values(by = ['State', 'County']).reset_index(drop = True)

# %% [markdown]
# ## Poverty census info

# %% [markdown]
# Data: https://data.census.gov/cedsci/all?q=county%20population

# %%
df = pd.read_csv('data/poverty.csv')

# %% [markdown]
# Sort out columns and index.

# %%
df.columns = df.iloc[0]

# %%
df.drop(df.index[0], inplace = True)

# %%
df = df.reset_index(drop = True)

# %% [markdown]
# Remove columns that contain the word 'Bound'. These are not needed.

# %%
df = df.loc[:, ~df.columns.str.contains('Bound')]

# %% [markdown]
# Remove columns that are percentages.

# %%
df = df.loc[:, ~df.columns.str.contains('Percent')]

# %% [markdown]
# Locate DC and change County FIPS so it isn't dropped during the next step.

# %%
df.loc[(df['County FIPS'] == '000') & (df['Name'] == 'District of Columbia')]
# Out:
# 0   State FIPS County FIPS Postal                  Name  \
# 328         11         000     DC  District of Columbia
#
# 0   Poverty Estimate All Ages Poverty Estimate Under Age 18  \
# 328                   107,279                        31,147
#
# 0   Poverty Estimate Ages 5-17 Median Household Income  \
# 328                     20,872                  60,729
#
# 0   Poverty Estimate Ages 0-4
# 328                     9,786

# %%
df.iloc[327:330, :]
# Out:
# 0   State FIPS County FIPS Postal                  Name  \
# 327         10         005     DE         Sussex County
# 328         11         000     DC  District of Columbia
# 329         11         001     DC  District of Columbia
#
# 0   Poverty Estimate All Ages Poverty Estimate Under Age 18  \
# 327                    26,924                         9,501
# 328                   107,279                        31,147
# 329                   107,279                        31,147
#
# 0   Poverty Estimate Ages 5-17 Median Household Income  \
# 327                      6,123                  48,582
# 328                     20,872                  60,729
# 329                     20,872                  60,729
#
# 0   Poverty Estimate Ages 0-4
# 327                       NaN
# 328                     9,786
# 329                       NaN

# %% [markdown]
# Nevermind. DC is in there alone and summed (as if it was a state). Just drop all County FIPS 000.

# %% [markdown]
# Drop all rows with county FIPS 000. These are just states summed. We don't need them. Might be useful to look at for any missing information later though.

# %%
drop = df.loc[(df['County FIPS'] == '000')]

# %%
df = df.drop(drop.index, axis = 0)

# %% [markdown]
# Drop Kalawao. No election results.

# %%
Kalawao = (pd.DataFrame(df.loc[561]))
df = df.drop(Kalawao)

# %% [markdown]
# Change state abbreviations to full names.

# %%
us_state_abbrev = {
    'AL': 'Alabama',
    'AK': 'Alaska',
    'AZ': 'Arizona',
    'AR': 'Arkansas',
    'CA': 'California',
    'CO': 'Colorado',
    'CT': 'Connecticut',
    'DE': 'Delaware',
    'FL': 'Florida',
    'GA': 'Georgia',
    'HI': 'Hawaii',
    'ID': 'Idaho',
    'IL': 'Illinois',
    'IN': 'Indiana',
    'IA': 'Iowa',
    'KS': 'Kansas',
    'KY': 'Kentucky',
    'LA': 'Louisiana',
    'ME': 'Maine',
    'MD': 'Maryland',
    'MA': 'Massachusetts',
    'MI': 'Michigan',
    'MN': 'Minnesota',
    'MS': 'Mississippi',
    'MO': 'Missouri',
    'MT': 'Montana',
    'NE': 'Nebraska',
    'NV': 'Nevada',
    'NH': 'New Hampshire',
    'NJ': 'New Jersey',
    'NM': 'New Mexico',
    'NY': 'New York',
    'NC': 'North Carolina',
    'ND': 'North Dakota',
    'OH': 'Ohio',
    'OK': 'Oklahoma',
    'OR': 'Oregon',
    'PA': 'Pennsylvania',
    'RI': 'Rhode Island',
    'SC': 'South Carolina',
    'SD': 'South Dakota',
    'TN': 'Tennessee',
    'TX': 'Texas',
    'UT': 'Utah',
    'VT': 'Vermont',
    'VA': 'Virginia',
    'WA': 'Washington',
    'WV': 'West Virginia',
    'WI': 'Wisconsin',
    'WY': 'Wyoming',
}

# %%
df.Postal = df.Postal.map(us_state_abbrev)

# %% [markdown]
# Drop unwanted columns.

# %%
df = df.drop(df.iloc[:, [0, 1, 6, 8]], axis = 1)

# %% [markdown]
# Chugach and Copper River are already combined into Valdez-Cordova so no need to change that. Renaming Wade Hampton to Kusilvak to match results.

# %%
df.loc[95]
# Out:
# 0
# Postal                                             Alaska
# Name                             Wade Hampton Census Area
# Poverty Estimate All Ages                           2,530
# Poverty Estimate Under Age 18                       1,403
# Median Household Income                            30,883
# Name: 95, dtype: object

# %%
df.loc[95]['Name'] = 'Kusilvak'

# %% [markdown]
# Remove punctuation.

# %%
def remove_punctuation(x):
    try:
        x = x.str.replace('[^\w\s]','')
    except:
        pass
    return x
df = df.apply(remove_punctuation)
# Out:
# <ipython-input-194-8e12971db89d>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   x = x.str.replace('[^\w\s]','')

# %% [markdown]
# Rename columns.

# %%
df.columns = ['state', 'county', 'poverty_total', 'poverty_under_18', 'median_household_income']

# %% [markdown]
# Sort and reset index.

# %%
df = df.sort_values(by = ['state', 'county']).reset_index(drop = True)

# %% [markdown]
# Drop empty rows at the bottom.

# %%
drop = df.loc[3142:]

# %%
df = df.drop(drop.index, axis = 0)

# %% [markdown]
# Change column types.

# %%
df[df.columns[2:]] = df[df.columns[2:]].astype(float)

# %% [markdown]
# Bedford, Virginia was a city and a county during this census. They were not separated for the elections.

# %%
bedfords = df.loc[2828:2829]

# %%
new_bedford = pd.DataFrame(bedfords.sum(numeric_only = False, axis = 0)).T

# %%
new_bedford['state'] = 'Virginia'
new_bedford['county'] = 'Bedford'
new_bedford['median_household_income'] = 56043 #pulled this from usa.com

# %%
df.drop(bedfords.index, axis = 0, inplace = True)

# %%
df = df.append(new_bedford)

# %% [markdown]
# Fill state name for DC.

# %%
df.loc[3141, 'state'] = 'District of Columbia'

# %%
df.loc[3141]
# Out:
# state                      District of Columbia
# county                     District of Columbia
# poverty_total                          107279.0
# poverty_under_18                        31147.0
# median_household_income                 60729.0
# Name: 3141, dtype: object

# %%
df.loc[df.county == 'District of Columbia']
# Out:
#                      state                county poverty_total  \
# 3141  District of Columbia  District of Columbia      107279.0
#
#      poverty_under_18  median_household_income
# 3141          31147.0                  60729.0

# %% [markdown]
# Rename Shannon County, SD to Oglala Lakota County to match other datasets.

# %%
df.loc[2415]
# Out:
# state                        South Dakota
# county                     Shannon County
# poverty_total                      6428.0
# poverty_under_18                   2631.0
# median_household_income           27307.0
# Name: 2415, dtype: object

# %% [markdown]
# Change datatype of some columns.

# %%
df[df.columns[2:]] = df[df.columns[2:]].astype(float)

# %%
poverty_df = df

# %%
poverty_df.head()
# Out:
#      state          county  poverty_total  poverty_under_18  \
# 0  Alabama  Autauga County         6459.0            2530.0
# 1  Alabama  Baldwin County        24056.0            8357.0
# 2  Alabama  Barbour County         6098.0            2145.0
# 3  Alabama     Bibb County         4316.0            1448.0
# 4  Alabama   Blount County         9358.0            3356.0
#
#    median_household_income
# 0                  53049.0
# 1                  47618.0
# 2                  33074.0
# 3                  35472.0
# 4                  42906.0

# %% [markdown]
# ## Merge race and poverty census data with results

# %% [markdown]
# Sort for merge.

# %%
poverty_df = poverty_df.sort_values(by = ['state', 'county']).reset_index(drop = True)

# %% [markdown]
# Sort for merge.

# %%
df_race = df_race.sort_values(by = ['State', 'County']).reset_index(drop = True)

# %% [markdown]
# Sort for merge.

# %%
total_results = total_results.sort_values(by = ['State', 'County']).reset_index(drop = True)

# %% [markdown]
# Merge race dataset and total results dataset.

# %%
df_race_results = df_race.reset_index(drop=True).merge(total_results.reset_index(drop=True), left_index=True, right_index=True)

# %%
df_race_results.loc[:, ['County_x', 'County_y', ]].tail()
# Out:
#                County_x           County_y
# 3136  Sweetwater County  Sweetwater County
# 3137       Teton County       Teton County
# 3138       Uinta County       Uinta County
# 3139    Washakie County    Washakie County
# 3140      Weston County      Weston County

# %% [markdown]
# Merge poverty with results and race.

# %%
df_poverty_race_results = df_race_results.reset_index(drop=True).merge(poverty_df.reset_index(drop=True), left_index=True, right_index=True)

# %%
df_poverty_race_results.loc[:, ['County_x', 'County_y', 'county']]
# Out:
#                               County_x                    County_y  \
# 0                       Autauga County              Autauga County
# 1                       Baldwin County              Baldwin County
# 2                       Barbour County              Barbour County
# 3                          Bibb County                 Bibb County
# 4                        Blount County               Blount County
# 5                       Bullock County              Bullock County
# 6                        Butler County               Butler County
# 7                       Calhoun County              Calhoun County
# 8                      Chambers County             Chambers County
# 9                      Cherokee County             Cherokee County
# 10                      Chilton County              Chilton County
# 11                      Choctaw County              Choctaw County
# 12                       Clarke County               Clarke County
# 13                         Clay County                 Clay County
# 14                     Cleburne County             Cleburne County
# 15                       Coffee County               Coffee County
# 16                      Colbert County              Colbert County
# 17                      Conecuh County              Conecuh County
# 18                        Coosa County                Coosa County
# 19                    Covington County            Covington County
# 20                     Crenshaw County             Crenshaw County
# 21                      Cullman County              Cullman County
# 22                         Dale County                 Dale County
# 23                       Dallas County               Dallas County
# 24                       DeKalb County               DeKalb County
# 25                       Elmore County               Elmore County
# 26                     Escambia County             Escambia County
# 27                       Etowah County               Etowah County
# 28                      Fayette County              Fayette County
# 29                     Franklin County             Franklin County
# 30                       Geneva County               Geneva County
# 31                       Greene County               Greene County
# 32                         Hale County                 Hale County
# 33                        Henry County                Henry County
# 34                      Houston County              Houston County
# 35                      Jackson County              Jackson County
# 36                    Jefferson County            Jefferson County
# 37                        Lamar County                Lamar County
# 38                   Lauderdale County           Lauderdale County
# 39                     Lawrence County             Lawrence County
# 40                          Lee County                  Lee County
# 41                    Limestone County            Limestone County
# 42                      Lowndes County              Lowndes County
# 43                        Macon County                Macon County
# 44                      Madison County              Madison County
# 45                      Marengo County              Marengo County
# 46                       Marion County               Marion County
# 47                     Marshall County             Marshall County
# 48                       Mobile County               Mobile County
# 49                       Monroe County               Monroe County
# 50                   Montgomery County           Montgomery County
# 51                       Morgan County               Morgan County
# 52                        Perry County                Perry County
# 53                      Pickens County              Pickens County
# 54                         Pike County                 Pike County
# 55                     Randolph County             Randolph County
# 56                      Russell County              Russell County
# 57                       Shelby County               Shelby County
# 58                     St Clair County             St Clair County
# 59                       Sumter County               Sumter County
# 60                    Talladega County            Talladega County
# 61                   Tallapoosa County           Tallapoosa County
# 62                   Tuscaloosa County           Tuscaloosa County
# 63                       Walker County               Walker County
# 64                   Washington County           Washington County
# 65                       Wilcox County               Wilcox County
# 66                      Winston County              Winston County
# 67              Aleutians East Borough              Aleutians East
# 68          Aleutians West Census Area              Aleutians West
# 69              Anchorage Municipality                   Anchorage
# 70                  Bethel Census Area                      Bethel
# 71                 Bristol Bay Borough                 Bristol Bay
# 72                      Denali Borough                      Denali
# 3021                 Monongalia County
# 3022                     Monroe County
# 3023                     Morgan County
# 3024                   Nicholas County
# 3025                       Ohio County
# 3026                  Pendleton County
# 3027                  Pleasants County
# 3028                 Pocahontas County
# 3029                    Preston County
# 3030                     Putnam County
# 3031                    Raleigh County
# 3032                   Randolph County
# 3033                    Ritchie County
# 3034                      Roane County
# 3035                    Summers County
# 3036                     Taylor County
# 3037                     Tucker County
# 3038                      Tyler County
# 3039                     Upshur County
# 3040                      Wayne County
# 3041                    Webster County
# 3042                     Wetzel County
# 3043                       Wirt County
# 3044                       Wood County
# 3045                    Wyoming County
# 3046                      Adams County
# 3047                    Ashland County
# 3048                     Barron County
# 3049                   Bayfield County
# 3050                      Brown County
# 3051                    Buffalo County
# 3052                    Burnett County
# 3053                    Calumet County
# 3054                   Chippewa County
# 3055                      Clark County
# 3056                   Columbia County
# 3057                   Crawford County
# 3058                       Dane County
# 3059                      Dodge County
# 3060                       Door County
# 3061                    Douglas County
# 3062                       Dunn County
# 3063                 Eau Claire County
# 3064                   Florence County
# 3065                Fond du Lac County
# 3066                     Forest County
# 3067                      Grant County
# 3068                      Green County
# 3069                 Green Lake County
# 3070                       Iowa County
# 3071                       Iron County
# 3072                    Jackson County
# 3073                  Jefferson County
# 3074                     Juneau County
# 3075                    Kenosha County
# 3076                   Kewaunee County
# 3077                  La Crosse County
# 3078                  Lafayette County
# 3079                   Langlade County
# 3080                    Lincoln County
# 3081                  Manitowoc County
# 3082                   Marathon County
# 3083                  Marinette County
# 3084                  Marquette County
# 3085                  Menominee County
# 3086                  Milwaukee County
# 3087                     Monroe County
# 3088                     Oconto County
# 3089                     Oneida County
# 3090                  Outagamie County
# 3091                    Ozaukee County
# 3092                      Pepin County
# 3093                     Pierce County
# 3094                       Polk County
# 3095                    Portage County
# 3096                      Price County
# 3097                     Racine County
# 3098                   Richland County
# 3099                       Rock County
# 3100                       Rusk County
# 3101                       Sauk County
# 3102                     Sawyer County
# 3103                    Shawano County
# 3104                  Sheboygan County
# 3105                   St Croix County
# 3106                     Taylor County
# 3107                Trempealeau County
# 3108                     Vernon County
# 3109                      Vilas County
# 3110                   Walworth County
# 3111                   Washburn County
# 3112                 Washington County
# 3113                   Waukesha County
# 3114                    Waupaca County
# 3115                   Waushara County
# 3116                  Winnebago County
# 3117                       Wood County
# 3118                     Albany County
# 3119                   Big Horn County
# 3120                   Campbell County
# 3121                     Carbon County
# 3122                   Converse County
# 3123                      Crook County
# 3124                    Fremont County
# 3125                     Goshen County
# 3126                Hot Springs County
# 3127                    Johnson County
# 3128                    Laramie County
# 3129                    Lincoln County
# 3130                    Natrona County
# 3131                   Niobrara County
# 3132                       Park County
# 3133                     Platte County
# 3134                   Sheridan County
# 3135                   Sublette County
# 3136                 Sweetwater County
# 3137                      Teton County
# 3138                      Uinta County
# 3139                   Washakie County
# 3140                     Weston County

# %%
df_all.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-2f43bb129972> in <module>
# ----> 1 df_all.head()
#
# NameError: name 'df_all' is not defined

# %%
df_all = df_poverty_race_results

# %%
dump(df_all, open('df_all.pkl', 'wb'))
