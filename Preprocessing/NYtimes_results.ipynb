# %%
import pandas as pd

# %%
df = pd.read_csv('nytimes_presidential_elections_2016_results_county.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4584 entries, 0 to 4583
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Clinton         4584 non-null   float64
#  1   Trump           4584 non-null   float64
#  2   Rpt             4584 non-null   int64
#  3   State           4584 non-null   object
#  4   Vote by county  3044 non-null   object
#  5   Vote by town    1540 non-null   object
#  6   Place           4584 non-null   object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 250.8+ KB

# %%
df.head()
# Out:
#     Clinton     Trump  Rpt    State Vote by county Vote by town       Place
# 0  151581.0  130614.0  100  Alabama      Jefferson          NaN   Jefferson
# 1   68429.0   91087.0  100  Alabama         Mobile          NaN      Mobile
# 2   62435.0   89199.0  100  Alabama        Madison          NaN     Madison
# 3   22927.0   72846.0  100  Alabama         Shelby          NaN      Shelby
# 4   58669.0   33928.0  100  Alabama     Montgomery          NaN  Montgomery

# %%
df = df.drop(['Rpt', 'Vote by town'], axis = 1)

# %%
df.head()
# Out:
#     Clinton     Trump    State Vote by county       Place
# 0  151581.0  130614.0  Alabama      Jefferson   Jefferson
# 1   68429.0   91087.0  Alabama         Mobile      Mobile
# 2   62435.0   89199.0  Alabama        Madison     Madison
# 3   22927.0   72846.0  Alabama         Shelby      Shelby
# 4   58669.0   33928.0  Alabama     Montgomery  Montgomery

# %%
df.duplicated().value_counts()
# Out:
# False    4584
# dtype: int64

# %%
df.loc[df.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [Clinton, Trump, State, Vote by county, Place]
# Index: []

# %%
drop = df.loc[(df['Clinton'] == 0.0) & (df['Trump'] == 0.0)].index

# %%
df.drop(drop, inplace = True)

# %%
df.State.value_counts().sort_values()
# Out:
# Delaware            3
# Hawaii              4
# Arizona            15
# Nevada             17
# New Jersey         21
# Wyoming            23
# Maryland           24
# Utah               29
# New Mexico         33
# Oregon             36
# Rhode Island       39
# Washington         39
# Idaho              44
# South Carolina     46
# North Dakota       53
# West Virginia      55
# Montana            56
# California         58
# New York           62
# Colorado           64
# Louisiana          64
# South Dakota       66
# Alabama            67
# Florida            67
# Pennsylvania       67
# Wisconsin          72
# Arkansas           75
# Oklahoma           77
# Mississippi        82
# Michigan           83
# Minnesota          87
# Ohio               88
# Indiana            92
# Nebraska           93
# Tennessee          95
# Iowa               99
# North Carolina    100
# Illinois          102
# Kansas            105
# Missouri          115
# Kentucky          120
# ...

# %%
df.State.isna().sum()
# Out:
# 0

# %%
pd.set_option('display.max_rows', 500)

# %%
(df.loc[df['State'].str.contains('Texas', case=False)])
# Out:
#        Clinton     Trump  State Vote by county          Place
# 3733  706471.0  544960.0  Texas         Harris         Harris
# 3734  458845.0  261865.0  Texas         Dallas         Dallas
# 3735  288001.0  345683.0  Texas        Tarrant        Tarrant
# 3736  319191.0  240161.0  Texas          Bexar          Bexar
# 3737  306475.0  126750.0  Texas         Travis         Travis
# 3738  139837.0  200395.0  Texas         Collin         Collin
# 3739  110000.0  169175.0  Texas         Denton         Denton
# 3740  134475.0  117212.0  Texas      Fort Bend      Fort Bend
# 3741  145509.0   54567.0  Texas        El Paso        El Paso
# 3742   45744.0  150188.0  Texas     Montgomery     Montgomery
# 3743   84252.0  104029.0  Texas     Williamson     Williamson
# 3744  118739.0   48608.0  Texas        Hidalgo        Hidalgo
# 3745   45503.0   73566.0  Texas      Galveston      Galveston
# 3746   43075.0   72653.0  Texas       Brazoria       Brazoria
# ...

# %%
(df.loc[df['Place'].str.contains('Kalawao', case=False)])
# Out:
# Empty DataFrame
# Columns: [Clinton, Trump, State, Vote by county, Place]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4582 entries, 0 to 4583
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Clinton         4582 non-null   float64
#  1   Trump           4582 non-null   float64
#  2   State           4582 non-null   object
#  3   Vote by county  3044 non-null   object
#  4   Place           4582 non-null   object
# dtypes: float64(2), object(3)
# memory usage: 214.8+ KB
