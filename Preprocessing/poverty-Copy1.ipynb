# %%
import pandas as pd
from pickle import dump
from pickle import load
pd.set_option("max_columns", None)
pd.set_option('max_rows', None)

# %%
df = pd.read_csv('poverty.csv')

# %%
df.head()
# Out:
#   Table with column headers in row 3   Unnamed: 1 Unnamed: 2      Unnamed: 3  \
# 0                         State FIPS  County FIPS     Postal            Name
# 1                                 00          000         US   United States
# 2                                 01          000         AL         Alabama
# 3                                 01          001         AL  Autauga County
# 4                                 01          003         AL  Baldwin County
#
#                   Unnamed: 4          Unnamed: 5          Unnamed: 6  \
# 0  Poverty Estimate All Ages  90% CI Lower Bound  90% CI Upper Bound
# 1                 46,215,956          45,975,650          46,456,262
# 2                    883,078             867,106             899,050
# 3                      6,459               5,075               7,843
# 4                     24,056              20,333              27,779
#
#                  Unnamed: 7          Unnamed: 8          Unnamed: 9  \
# 0  Poverty Percent All Ages  90% CI Lower Bound  90% CI Upper Bound
# 1                      15.3                15.2                15.4
# 2                      18.9                18.6                19.2
# 3                      11.9                 9.3                14.5
# 4                      13.3                11.2                15.4
#
#                      Unnamed: 10         Unnamed: 11         Unnamed: 12  \
# 0  Poverty Estimate Under Age 18  90% CI Lower Bound  90% CI Upper Bound
# 1                     15,749,129          15,621,395          15,876,863
# 2                        305,292             296,223             314,361
# 3                          2,530               1,956               3,104
# 4                          8,357               6,775               9,939
#
#                     Unnamed: 13         Unnamed: 14         Unnamed: 15  \
# 0  Poverty Percent Under Age 18  90% CI Lower Bound  90% CI Upper Bound
# 1                          21.6                21.4                21.8
# 2                          27.4                26.6                28.2
# 3                          17.5                13.5                21.5
# 4                          20.2                16.4                24.0
#
#                   Unnamed: 16         Unnamed: 17         Unnamed: 18  \
# 0  Poverty Estimate Ages 5-17  90% CI Lower Bound  90% CI Upper Bound
# 1                  10,484,513          10,394,015          10,575,011
# 2                     207,778             199,900             215,656
# 3                       1,791               1,397               2,185
# 4                       5,734               4,655               6,813
#
#                  Unnamed: 19         Unnamed: 20         Unnamed: 21  \
# 0  Poverty Percent Ages 5-17  90% CI Lower Bound  90% CI Upper Bound
# 1                       19.8                19.6                20.0
# 2                       25.6                24.6                26.6
# 3                       16.4                12.8                20.0
# 4                       18.9                15.3                22.5
#
#                Unnamed: 22         Unnamed: 23         Unnamed: 24  \
# 0  Median Household Income  90% CI Lower Bound  90% CI Upper Bound
# 1                   50,046              49,982              50,110
# 2                   40,538              40,081              40,995
# 3                   53,049              49,486              56,612
# 4                   47,618              45,169              50,067
#
#                  Unnamed: 25         Unnamed: 26         Unnamed: 27  \
# 0  Poverty Estimate Ages 0-4  90% CI Lower Bound  90% CI Upper Bound
# 1                  4,961,524           4,910,772           5,012,276
# 2                     93,895              89,540              98,250
# 3                        NaN                 NaN                 NaN
# 4                        NaN                 NaN                 NaN
#
#                 Unnamed: 28         Unnamed: 29         Unnamed: 30
# 0  Poverty Percent Ages 0-4  90% CI Lower Bound  90% CI Upper Bound
# 1                      25.0                24.8                25.2
# 2                      31.3                29.8                32.8
# 3                       NaN                 NaN                 NaN
# 4                       NaN                 NaN                 NaN

# %%
df.columns = df.iloc[0]

# %%
df.head()
# Out:
# 0  State FIPS  County FIPS  Postal            Name  Poverty Estimate All Ages  \
# 0  State FIPS  County FIPS  Postal            Name  Poverty Estimate All Ages
# 1          00          000      US   United States                 46,215,956
# 2          01          000      AL         Alabama                    883,078
# 3          01          001      AL  Autauga County                      6,459
# 4          01          003      AL  Baldwin County                     24,056
#
# 0  90% CI Lower Bound  90% CI Upper Bound  Poverty Percent All Ages  \
# 0  90% CI Lower Bound  90% CI Upper Bound  Poverty Percent All Ages
# 1          45,975,650          46,456,262                      15.3
# 2             867,106             899,050                      18.9
# 3               5,075               7,843                      11.9
# 4              20,333              27,779                      13.3
#
# 0  90% CI Lower Bound  90% CI Upper Bound  Poverty Estimate Under Age 18  \
# 0  90% CI Lower Bound  90% CI Upper Bound  Poverty Estimate Under Age 18
# 1                15.2                15.4                     15,749,129
# 2                18.6                19.2                        305,292
# 3                 9.3                14.5                          2,530
# 4                11.2                15.4                          8,357
#
# 0  90% CI Lower Bound  90% CI Upper Bound  Poverty Percent Under Age 18  \
# 0  90% CI Lower Bound  90% CI Upper Bound  Poverty Percent Under Age 18
# 1          15,621,395          15,876,863                          21.6
# 2             296,223             314,361                          27.4
# 3               1,956               3,104                          17.5
# 4               6,775               9,939                          20.2
#
# 0  90% CI Lower Bound  90% CI Upper Bound  Poverty Estimate Ages 5-17  \
# 0  90% CI Lower Bound  90% CI Upper Bound  Poverty Estimate Ages 5-17
# 1                21.4                21.8                  10,484,513
# 2                26.6                28.2                     207,778
# 3                13.5                21.5                       1,791
# 4                16.4                24.0                       5,734
#
# 0  90% CI Lower Bound  90% CI Upper Bound  Poverty Percent Ages 5-17  \
# 0  90% CI Lower Bound  90% CI Upper Bound  Poverty Percent Ages 5-17
# 1          10,394,015          10,575,011                       19.8
# 2             199,900             215,656                       25.6
# 3               1,397               2,185                       16.4
# 4               4,655               6,813                       18.9
#
# 0  90% CI Lower Bound  90% CI Upper Bound  Median Household Income  \
# 0  90% CI Lower Bound  90% CI Upper Bound  Median Household Income
# 1                19.6                20.0                   50,046
# 2                24.6                26.6                   40,538
# 3                12.8                20.0                   53,049
# 4                15.3                22.5                   47,618
#
# 0  90% CI Lower Bound  90% CI Upper Bound  Poverty Estimate Ages 0-4  \
# 0  90% CI Lower Bound  90% CI Upper Bound  Poverty Estimate Ages 0-4
# 1              49,982              50,110                  4,961,524
# 2              40,081              40,995                     93,895
# 3              49,486              56,612                        NaN
# 4              45,169              50,067                        NaN
#
# 0  90% CI Lower Bound  90% CI Upper Bound  Poverty Percent Ages 0-4  \
# 0  90% CI Lower Bound  90% CI Upper Bound  Poverty Percent Ages 0-4
# 1           4,910,772           5,012,276                      25.0
# 2              89,540              98,250                      31.3
# 3                 NaN                 NaN                       NaN
# 4                 NaN                 NaN                       NaN
#
# 0  90% CI Lower Bound  90% CI Upper Bound
# 0  90% CI Lower Bound  90% CI Upper Bound
# 1                24.8                25.2
# 2                29.8                32.8
# 3                 NaN                 NaN
# 4                 NaN                 NaN

# %%
df.drop(df.index[0], inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3198 entries, 1 to 3198
# Data columns (total 31 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   State FIPS                     3197 non-null   object
#  1   County FIPS                    3195 non-null   object
#  2   Postal                         3195 non-null   object
#  3   Name                           3195 non-null   object
#  4   Poverty Estimate All Ages      3195 non-null   object
#  5   90% CI Lower Bound             3195 non-null   object
#  6   90% CI Upper Bound             3195 non-null   object
#  7   Poverty Percent All Ages       3195 non-null   object
#  8   90% CI Lower Bound             3195 non-null   object
#  9   90% CI Upper Bound             3195 non-null   object
#  10  Poverty Estimate Under Age 18  3195 non-null   object
#  11  90% CI Lower Bound             3195 non-null   object
#  12  90% CI Upper Bound             3195 non-null   object
#  13  Poverty Percent Under Age 18   3195 non-null   object
#  14  90% CI Lower Bound             3195 non-null   object
#  15  90% CI Upper Bound             3195 non-null   object
#  16  Poverty Estimate Ages 5-17     3195 non-null   object
#  17  90% CI Lower Bound             3195 non-null   object
#  18  90% CI Upper Bound             3195 non-null   object
#  19  Poverty Percent Ages 5-17      3195 non-null   object
#  20  90% CI Lower Bound             3195 non-null   object
#  21  90% CI Upper Bound             3195 non-null   object
#  22  Median Household Income        3195 non-null   object
#  23  90% CI Lower Bound             3195 non-null   object
#  24  90% CI Upper Bound             3195 non-null   object
#  25  Poverty Estimate Ages 0-4      52 non-null     object
#  26  90% CI Lower Bound             52 non-null     object
#  27  90% CI Upper Bound             52 non-null     object
#  28  Poverty Percent Ages 0-4       52 non-null     object
#  29  90% CI Lower Bound             52 non-null     object
#  30  90% CI Upper Bound             52 non-null     object
# dtypes: object(31)
# memory usage: 799.5+ KB

# %%
df.head()
# Out:
# 0 State FIPS County FIPS Postal            Name Poverty Estimate All Ages  \
# 1         00         000     US   United States                46,215,956
# 2         01         000     AL         Alabama                   883,078
# 3         01         001     AL  Autauga County                     6,459
# 4         01         003     AL  Baldwin County                    24,056
# 5         01         005     AL  Barbour County                     6,098
#
# 0 90% CI Lower Bound 90% CI Upper Bound Poverty Percent All Ages  \
# 1         45,975,650         46,456,262                     15.3
# 2            867,106            899,050                     18.9
# 3              5,075              7,843                     11.9
# 4             20,333             27,779                     13.3
# 5              4,749              7,447                     25.3
#
# 0 90% CI Lower Bound 90% CI Upper Bound Poverty Estimate Under Age 18  \
# 1               15.2               15.4                    15,749,129
# 2               18.6               19.2                       305,292
# 3                9.3               14.5                         2,530
# 4               11.2               15.4                         8,357
# 5               19.7               30.9                         2,145
#
# 0 90% CI Lower Bound 90% CI Upper Bound Poverty Percent Under Age 18  \
# 1         15,621,395         15,876,863                         21.6
# 2            296,223            314,361                         27.4
# 3              1,956              3,104                         17.5
# 4              6,775              9,939                         20.2
# 5              1,641              2,649                         36.2
#
# 0 90% CI Lower Bound 90% CI Upper Bound Poverty Estimate Ages 5-17  \
# 1               21.4               21.8                 10,484,513
# 2               26.6               28.2                    207,778
# 3               13.5               21.5                      1,791
# 4               16.4               24.0                      5,734
# 5               27.7               44.7                      1,458
#
# 0 90% CI Lower Bound 90% CI Upper Bound Poverty Percent Ages 5-17  \
# 1         10,394,015         10,575,011                      19.8
# 2            199,900            215,656                      25.6
# 3              1,397              2,185                      16.4
# 4              4,655              6,813                      18.9
# 5              1,114              1,802                      34.3
#
# 0 90% CI Lower Bound 90% CI Upper Bound Median Household Income  \
# 1               19.6               20.0                  50,046
# 2               24.6               26.6                  40,538
# 3               12.8               20.0                  53,049
# 4               15.3               22.5                  47,618
# 5               26.2               42.4                  33,074
#
# 0 90% CI Lower Bound 90% CI Upper Bound Poverty Estimate Ages 0-4  \
# 1             49,982             50,110                 4,961,524
# 2             40,081             40,995                    93,895
# 3             49,486             56,612                       NaN
# 4             45,169             50,067                       NaN
# 5             30,589             35,559                       NaN
#
# 0 90% CI Lower Bound 90% CI Upper Bound Poverty Percent Ages 0-4  \
# 1          4,910,772          5,012,276                     25.0
# 2             89,540             98,250                     31.3
# 3                NaN                NaN                      NaN
# 4                NaN                NaN                      NaN
# 5                NaN                NaN                      NaN
#
# 0 90% CI Lower Bound 90% CI Upper Bound
# 1               24.8               25.2
# 2               29.8               32.8
# 3                NaN                NaN
# 4                NaN                NaN
# 5                NaN                NaN

# %% [markdown]
# Remove columns that contain the word 'Bound'. These are not needed.

# %%
df = df.loc[:, ~df.columns.str.contains('Bound')]

# %% [markdown]
# Remove columns that are percentages.

# %%
df = df.loc[:, ~df.columns.str.contains('Percent')]

# %% [markdown]
# Locate DC and change County FIPS so it isn't dropped during the next step.

# %%
df.loc[(df['County FIPS'] == '000') & (df['Name'] == 'District of Columbia')]
# Out:
# 0   State FIPS County FIPS Postal                  Name  \
# 329         11         000     DC  District of Columbia
#
# 0   Poverty Estimate All Ages Poverty Estimate Under Age 18  \
# 329                   107,279                        31,147
#
# 0   Poverty Estimate Ages 5-17 Median Household Income  \
# 329                     20,872                  60,729
#
# 0   Poverty Estimate Ages 0-4
# 329                     9,786

# %%
df.iloc[327:330, :]
# Out:
# 0   State FIPS County FIPS Postal                  Name  \
# 328         10         005     DE         Sussex County
# 329         11         000     DC  District of Columbia
# 330         11         001     DC  District of Columbia
#
# 0   Poverty Estimate All Ages Poverty Estimate Under Age 18  \
# 328                    26,924                         9,501
# 329                   107,279                        31,147
# 330                   107,279                        31,147
#
# 0   Poverty Estimate Ages 5-17 Median Household Income  \
# 328                      6,123                  48,582
# 329                     20,872                  60,729
# 330                     20,872                  60,729
#
# 0   Poverty Estimate Ages 0-4
# 328                       NaN
# 329                     9,786
# 330                       NaN

# %% [markdown]
# Nevermind. DC is in there alone and summed (as if it was a state). Just drop all County FIPS 000.

# %% [markdown]
# Drop all rows with county FIPS 000. These are just states summed. We don't need them. Might be useful to look at for any missing information later though.

# %%
drop = df.loc[(df['County FIPS'] == '000')]

# %%
df = df.drop(drop.index, axis = 0)

# %% [markdown]
# Check on the Hawaii counties. May need to drop Kalawao (no election results. Very low pop) Change states to full words. Look for Puerto Rico. Strip county, borough, etc.

# %%
df.loc[(df['Postal'] == 'HI')]
# Out:
# 0   State FIPS County FIPS Postal             Name Poverty Estimate All Ages  \
# 560         15         001     HI    Hawaii County                    33,285
# 561         15         003     HI  Honolulu County                    87,411
# 562         15         005     HI   Kalawao County                         .
# 563         15         007     HI     Kauai County                     8,012
# 564         15         009     HI      Maui County                    18,214
#
# 0   Poverty Estimate Under Age 18 Poverty Estimate Ages 5-17  \
# 560                        10,022                      6,429
# 561                        25,409                     15,704
# 562                             .                          .
# 563                         2,360                      1,563
# 564                         5,804                      3,611
#
# 0   Median Household Income Poverty Estimate Ages 0-4
# 560                  46,444                       NaN
# 561                  67,519                       NaN
# 562                       .                       NaN
# 563                  52,714                       NaN
# 564                  56,206                       NaN

# %%
Kalawao = (pd.DataFrame(df.loc[562]))
df = df.drop(Kalawao)

# %%
df.head()
# Out:
# 0 State FIPS County FIPS Postal            Name Poverty Estimate All Ages  \
# 3         01         001     AL  Autauga County                     6,459
# 4         01         003     AL  Baldwin County                    24,056
# 5         01         005     AL  Barbour County                     6,098
# 6         01         007     AL     Bibb County                     4,316
# 7         01         009     AL   Blount County                     9,358
#
# 0 Poverty Estimate Under Age 18 Poverty Estimate Ages 5-17  \
# 3                         2,530                      1,791
# 4                         8,357                      5,734
# 5                         2,145                      1,458
# 6                         1,448                        938
# 7                         3,356                      2,202
#
# 0 Median Household Income Poverty Estimate Ages 0-4
# 3                  53,049                       NaN
# 4                  47,618                       NaN
# 5                  33,074                       NaN
# 6                  35,472                       NaN
# 7                  42,906                       NaN

# %%
us_state_abbrev = {
    'AL': 'Alabama',
    'AK': 'Alaska',
    'AZ': 'Arizona',
    'AR': 'Arkansas',
    'CA': 'California',
    'CO': 'Colorado',
    'CT': 'Connecticut',
    'DE': 'Delaware',
    'FL': 'Florida',
    'GA': 'Georgia',
    'HI': 'Hawaii',
    'ID': 'Idaho',
    'IL': 'Illinois',
    'IN': 'Indiana',
    'IA': 'Iowa',
    'KS': 'Kansas',
    'KY': 'Kentucky',
    'LA': 'Louisiana',
    'ME': 'Maine',
    'MD': 'Maryland',
    'MA': 'Massachusetts',
    'MI': 'Michigan',
    'MN': 'Minnesota',
    'MS': 'Mississippi',
    'MO': 'Missouri',
    'MT': 'Montana',
    'NE': 'Nebraska',
    'NV': 'Nevada',
    'NH': 'New Hampshire',
    'NJ': 'New Jersey',
    'NM': 'New Mexico',
    'NY': 'New York',
    'NC': 'North Carolina',
    'ND': 'North Dakota',
    'OH': 'Ohio',
    'OK': 'Oklahoma',
    'OR': 'Oregon',
    'PA': 'Pennsylvania',
    'RI': 'Rhode Island',
    'SC': 'South Carolina',
    'SD': 'South Dakota',
    'TN': 'Tennessee',
    'TX': 'Texas',
    'UT': 'Utah',
    'VT': 'Vermont',
    'VA': 'Virginia',
    'WA': 'Washington',
    'WV': 'West Virginia',
    'WI': 'Wisconsin',
    'WY': 'Wyoming',
}

# %%
df.Postal = df.Postal.map(us_state_abbrev)

# %%
df.head()
# Out:
# 0 State FIPS County FIPS   Postal            Name Poverty Estimate All Ages  \
# 3         01         001  Alabama  Autauga County                     6,459
# 4         01         003  Alabama  Baldwin County                    24,056
# 5         01         005  Alabama  Barbour County                     6,098
# 6         01         007  Alabama     Bibb County                     4,316
# 7         01         009  Alabama   Blount County                     9,358
#
# 0 Poverty Estimate Under Age 18 Poverty Estimate Ages 5-17  \
# 3                         2,530                      1,791
# 4                         8,357                      5,734
# 5                         2,145                      1,458
# 6                         1,448                        938
# 7                         3,356                      2,202
#
# 0 Median Household Income Poverty Estimate Ages 0-4
# 3                  53,049                       NaN
# 4                  47,618                       NaN
# 5                  33,074                       NaN
# 6                  35,472                       NaN
# 7                  42,906                       NaN

# %%
df = df.drop(df.iloc[:, [0, 1, 6, 8]], axis = 1)

# %%
df.head()
# Out:
# 0   Postal            Name Poverty Estimate All Ages  \
# 3  Alabama  Autauga County                     6,459
# 4  Alabama  Baldwin County                    24,056
# 5  Alabama  Barbour County                     6,098
# 6  Alabama     Bibb County                     4,316
# 7  Alabama   Blount County                     9,358
#
# 0 Poverty Estimate Under Age 18 Median Household Income
# 3                         2,530                  53,049
# 4                         8,357                  47,618
# 5                         2,145                  33,074
# 6                         1,448                  35,472
# 7                         3,356                  42,906

# %%
df['Name'] = df['Name'].str.replace('(Borough|County|Area|Census|Municipality|and|City|Municipali)', '')
# Out:
# <ipython-input-23-d17b4f397bd8>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Name'] = df['Name'].str.replace('(Borough|County|Area|Census|Municipality|and|City|Municipali)', '')

# %% [markdown]
# Chugach and Copper River are already combined into Valdez-Cordova so no need to change that. Renaming Wade Hampton to Kusilvak to match results.

# %%
df.loc[df['Postal'] == 'Alaska']
# Out:
# 0   Postal                     Name Poverty Estimate All Ages  \
# 71  Alaska          Aleutians East                        527
# 72  Alaska         Aleutians West                         482
# 73  Alaska               Anchorage                     27,351
# 74  Alaska                 Bethel                       3,794
# 75  Alaska             Bristol Bay                         86
# 76  Alaska                  Denali                        102
# 77  Alaska             Dillingham                         995
# 78  Alaska    Fairbanks North Star                      8,804
# 79  Alaska                  Haines                        304
# 80  Alaska          Hoonah-Angoon                         416
# 81  Alaska                  Juneau                      2,524
# 82  Alaska         Kenai Peninsula                      5,798
# 83  Alaska       Ketchikan Gateway                      1,335
# 84  Alaska              Kodiak Isl                      1,116
# 85  Alaska         Lake  Peninsula                        287
# 86  Alaska       Matanuska-Susitna                      9,618
# 87  Alaska                   Nome                       2,295
# 88  Alaska             North Slope                      1,074
# 89  Alaska        Northwest Arctic                      1,494
# 90  Alaska             Petersburg                         406
# 91  Alaska  Prince of Wales-Hyder                         957
# 92  Alaska                   Sitka                        800
# 93  Alaska                 Skagway                         40
# 94  Alaska    Southeast Fairbanks                         938
# 95  Alaska         Valdez-Cordova                         858
# 96  Alaska           Wade Hampton                       2,530
# 97  Alaska              Wrangell                          307
# 98  Alaska                 Yakutat                         97
# 99  Alaska          Yukon-Koyukuk                       1,512
#
# 0  Poverty Estimate Under Age 18 Median Household Income
# 71                            61                  47,077
# 72                            86                  58,517
# 73                         9,009                  70,524
# 74                         1,842                  45,481
# 75                            21                  62,912
# 76                            28                  61,004
# 77                           458                  46,845
# 78                         3,087                  60,472
# 79                            97                  46,111
# 80                           107                  38,122
# 81                           723                  69,844
# 82                         1,847                  57,347
# 83                           459                  58,073
# 84                           382                  59,847
# 85                           117                  39,794
# 86                         3,565                  68,670
# 87                           989                  43,147
# 88                           294                  68,744
# 89                           572                  49,466
# 90                           135                  52,294
# 91                           334                  40,756
# 92                           244                  58,000
# 93                            11                  58,550
# 94                           393                  54,508
# 95                           262                  60,297
# 96                         1,403                  30,883
# 97                           102                  42,752
# 98                            40                  49,331
# 99                           541                  35,177

# %%
df.loc[96]['Name'] = 'Kusilvak'

# %% [markdown]
# Remove punctuation.

# %%
def remove_punctuation(x):
    try:
        x = x.str.replace('[^\w\s]','')
    except:
        pass
    return x
df = df.apply(remove_punctuation)
# Out:
# <ipython-input-26-8e12971db89d>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   x = x.str.replace('[^\w\s]','')

# %%
df.head()
# Out:
# 0   Postal      Name Poverty Estimate All Ages Poverty Estimate Under Age 18  \
# 3  Alabama  Autauga                       6459                          2530
# 4  Alabama  Baldwin                      24056                          8357
# 5  Alabama  Barbour                       6098                          2145
# 6  Alabama     Bibb                       4316                          1448
# 7  Alabama   Blount                       9358                          3356
#
# 0 Median Household Income
# 3                   53049
# 4                   47618
# 5                   33074
# 6                   35472
# 7                   42906

# %%
df.columns = ['state', 'county', 'poverty_total', 'poverty_under_18', 'median_household_income']

# %%
df = df.sort_values(by = ['state', 'county']).reset_index(drop = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3145 entries, 0 to 3144
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   state                    3141 non-null   object
#  1   county                   3142 non-null   object
#  2   poverty_total            3142 non-null   object
#  3   poverty_under_18         3142 non-null   object
#  4   median_household_income  3142 non-null   object
# dtypes: object(5)
# memory usage: 123.0+ KB

# %%
df[df.columns[2:]] = df[df.columns[2:]].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3145 entries, 0 to 3144
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   state                    3141 non-null   object
#  1   county                   3142 non-null   object
#  2   poverty_total            3142 non-null   float64
#  3   poverty_under_18         3142 non-null   float64
#  4   median_household_income  3142 non-null   float64
# dtypes: float64(3), object(2)
# memory usage: 123.0+ KB

# %%
df.head()
# Out:
#      state    county  poverty_total  poverty_under_18  median_household_income
# 0  Alabama  Autauga          6459.0            2530.0                  53049.0
# 1  Alabama  Baldwin         24056.0            8357.0                  47618.0
# 2  Alabama  Barbour          6098.0            2145.0                  33074.0
# 3  Alabama     Bibb          4316.0            1448.0                  35472.0
# 4  Alabama   Blount          9358.0            3356.0                  42906.0

# %%
race = load(open('results_race_with_alaska.pkl', 'rb'))
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# <ipython-input-38-e1ad48e598d6> in <module>
# ----> 1 race = load(open('results_race_with_alaska.pkl', 'rb'))
#
# EOFError: Ran out of input

# %%
df.loc[~df['county'].isin(race['County'])]

# %%
dump(df, open('df_poverty.pkl', 'wb'))
