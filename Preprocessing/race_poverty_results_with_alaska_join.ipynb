# %% [markdown]
# Bring in results with alaska and target. Bring in census pull with alaska. See if you can join them.

# %%
import pandas as pd
from pickle import load
from pickle import dump
import numpy as np
pd.set_option("max_rows", None)
pd.set_option("max_columns", None)

# %%
results = load(open('../PICKLES/combined_results.pkl', 'rb'))

# %%
race = load(open('../PICKLES/df_race1.pkl', 'rb'))

# %%
poverty = load(open('../PICKLES/poverty.pkl', 'rb'))

# %%
results.head()
# Out:
#      State    County  2016_total_votes    Obama   Romney  2012_total_votes  \
# 0  Alabama  Autauga            24661.0   6354.0  17366.0           23909.0
# 1  Alabama  Baldwin            94090.0  18329.0  65772.0           84988.0
# 2  Alabama  Barbour            10390.0   5873.0   5539.0           11459.0
# 3  Alabama     Bibb             8748.0   2200.0   6131.0            8391.0
# 4  Alabama   Blount            25384.0   2961.0  20741.0           23980.0
#
#    2010_land_area  Density central_outlying Target
# 0             594     93.0          Central  Trump
# 1            1590    128.0          Central  Trump
# 2             885     30.0          Central  Trump
# 3             623     36.0         Outlying  Trump
# 4             645     89.0         Outlying  Trump

# %%
race.head()
# Out:
# 1              id  total_pop  total_pop_one_race  pop_white  \
# 0  0500000US01001    58805.0             55648.0    42160.0
# 1  0500000US01003   231767.0            216743.0   189399.0
# 2  0500000US01005    25223.0             24523.0    11317.0
# 3  0500000US01007    22293.0             21534.0    16555.0
# 4  0500000US01009    59134.0             55478.0    50663.0
#
# 1  pop_african_american  pop_native  pop_asian  pop_islander  pop_other  \
# 0               11445.0       217.0      881.0          35.0      910.0
# 1               18217.0      1582.0     2067.0         143.0     5335.0
# 2               11933.0       116.0      117.0           1.0     1039.0
# 3                4413.0        60.0       32.0           9.0      465.0
# 4                 845.0       337.0      178.0          24.0     3431.0
#
# 1  total_pop_two_races   County     State
# 0               3157.0  Autauga   Alabama
# 1              15024.0  Baldwin   Alabama
# ...

# %%
results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3141 entries, 0 to 3140
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State             3141 non-null   object
#  1   County            3141 non-null   object
#  2   2016_total_votes  3141 non-null   float64
#  3   Obama             3141 non-null   float64
#  4   Romney            3141 non-null   float64
#  5   2012_total_votes  3141 non-null   float64
#  6   2010_land_area    3141 non-null   int64
#  7   Density           3141 non-null   float64
#  8   central_outlying  3141 non-null   object
#  9   Target            3141 non-null   object
# dtypes: float64(5), int64(1), object(4)
# memory usage: 245.5+ KB

# %%
race.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3141 entries, 0 to 3140
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    3141 non-null   object
#  1   total_pop             3141 non-null   float64
#  2   total_pop_one_race    3141 non-null   float64
#  3   pop_white             3141 non-null   float64
#  4   pop_african_american  3141 non-null   float64
#  5   pop_native            3141 non-null   float64
#  6   pop_asian             3141 non-null   float64
#  7   pop_islander          3141 non-null   float64
#  8   pop_other             3141 non-null   float64
#  9   total_pop_two_races   3141 non-null   float64
#  10  County                3141 non-null   object
#  11  State                 3141 non-null   object
# dtypes: float64(9), object(3)
# memory usage: 294.6+ KB

# %%
df = race.reset_index(drop=True).merge(results.reset_index(drop=True), left_index=True, right_index=True)

# %%
df = df.replace('rural', 'Rural')

# %%
df.tail()
# Out:
#                   id  total_pop  total_pop_one_race  pop_white  \
# 3136  0500000US56037    42272.0             38061.0    34389.0
# 3137  0500000US56039    23331.0             21179.0    19202.0
# 3138  0500000US56041    20450.0             19269.0    18007.0
# 3139  0500000US56043     7685.0              7113.0     6600.0
# 3140  0500000US56045     6838.0              6498.0     6197.0
#
#       pop_african_american  pop_native  pop_asian  pop_islander  pop_other  \
# 3136                 366.0       433.0      295.0          70.0     2508.0
# 3137                  55.0       185.0      317.0           5.0     1415.0
# 3138                  66.0       191.0      114.0          27.0      864.0
# 3139                  12.0        77.0       33.0           3.0      388.0
# 3140                  30.0        97.0       27.0           9.0      138.0
#
#       total_pop_two_races    County_x   State_x  State_y     County_y  \
# ...

# %%
race_poverty_results = df.reset_index(drop=True).merge(poverty.reset_index(drop=True), left_index=True, right_index=True)

# %%
race_poverty_results.loc[race_poverty_results.state == 'Alaska']
# Out:
#                 id  total_pop  total_pop_one_race  pop_white  \
# 67  0500000US02013     3420.0              3212.0      684.0
# 68  0500000US02016     5232.0              4858.0     1667.0
# 69  0500000US02020   291247.0            250445.0   164446.0
# 70  0500000US02050    18666.0             17650.0     1665.0
# 71  0500000US02060      844.0               701.0      370.0
# 72  0500000US02068     1619.0              1480.0     1382.0
# 73  0500000US02070     4857.0              4361.0      799.0
# 74  0500000US02090    95655.0             83485.0    65971.0
# 75  0500000US02100     2080.0              1838.0     1589.0
# 76  0500000US02105     2365.0              2081.0     1147.0
# 77  0500000US02110    32255.0             27318.0    20124.0
# 78  0500000US02122    58799.0             52811.0    46382.0
# 79  0500000US02130    13948.0             12246.0     8430.0
# 80  0500000US02150    13101.0             11794.0     6570.0
# ...

# %%
dump(race_poverty_results, open('race_poverty_results.pkl', 'wb'))

# %%
dump(df, open('results_race_with_alaska.pkl', 'wb'))
