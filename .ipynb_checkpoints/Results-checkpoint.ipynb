# %%
import pandas as pd

# %%
df = pd.read_csv('2016 Presidential Election Analysis.csv')

# %%
df.head()
# Out:
#   State Code     County Name  County Population  Clinton or Trump State  \
# 0         AL  Autauga County             55,347                   Trump
# 1         AL  Baldwin County            203,709                   Trump
# 2         AL  Barbour County             26,489                   Trump
# 3         AL     Bibb County             22,583                   Trump
# 4         AL   Blount County             57,673                   Trump
#
#    Clinton     Trump     Total  % Clinton % Trump  Vote Difference C-T   ...  \
# 0    5,908    18,110    24,661     23.96%  73.44%              (12,202)  ...
# 1   18,409    72,780    94,090     19.57%  77.35%              (54,371)  ...
# 2    4,848     5,431    10,390     46.66%  52.27%                 (583)  ...
# 3    1,874     6,733     8,748     21.42%  76.97%               (4,859)  ...
# 4    2,150    22,808    25,384      8.47%  89.85%              (20,658)  ...
#
#   County FIPS Code CBSA Code CSA Code                 CBSA Title  \
# ...

# %%
df.loc[df['County FIPS Code'] == 39.0]
# Out:
#      State Code         County Name  County Population   \
# 19           AL    Covington County             37,835
# 102          AR       Dallas County              7,604
# 177          CA       Madera County            154,998
# 236          CO       Elbert County             24,735
# 310          FL      Gadsden County             46,036
# 378          GA       Camden County             52,102
# 541          ID       Elmore County             25,876
# 585          IL      De Witt County             16,247
# 687          IN      Elkhart County            203,474
# 779          IA       Clarke County              9,259
# 878          KS      Decatur County              2,932
# 983          KY     Carlisle County              4,874
# 1103         LA   Evangeline Parish             33,743
# 1182         MD     Somerset County             25,768
# 1221         MI     Crawford County             13,801
# 1304         MN        Dodge County             20,364
# ...

# %%
us_state_abbrev = {
    'AL': 'Alabama',
    'AK': 'Alaska',
    'AZ': 'Arizona',
    'AR': 'Arkansas',
    'CA': 'California',
    'CO': 'Colorado',
    'CT': 'Connecticut',
    'DE': 'Delaware',
    'FL': 'Florida',
    'GA': 'Georgia',
    'HI': 'Hawaii',
    'ID': 'Idaho',
    'IL': 'Illinois',
    'IN': 'Indiana',
    'IA': 'Iowa',
    'KS': 'Kansas',
    'KY': 'Kentucky',
    'LA': 'Louisiana',
    'ME': 'Maine',
    'MD': 'Maryland',
    'MA': 'Massachusetts',
    'MI': 'Michigan',
    'MN': 'Minnesota',
    'MS': 'Mississippi',
    'MO': 'Missouri',
    'MT': 'Montana',
    'NE': 'Nebraska',
    'NV': 'Nevada',
    'NH': 'New Hampshire',
    'NJ': 'New Jersey',
    'NM': 'New Mexico',
    'NY': 'New York',
    'NC': 'North Carolina',
    'ND': 'North Dakota',
    'OH': 'Ohio',
    'OK': 'Oklahoma',
    'OR': 'Oregon',
    'PA': 'Pennsylvania',
    'RI': 'Rhode Island',
    'SC': 'South Carolina',
    'SD': 'South Dakota',
    'TN': 'Tennessee',
    'TX': 'Texas',
    'UT': 'Utah',
    'VT': 'Vermont',
    'VA': 'Virginia',
    'WA': 'Washington',
    'WV': 'West Virginia',
    'WI': 'Wisconsin',
    'WY': 'Wyoming',
}

# %%
df['State Code'] = df['State Code'].map(us_state_abbrev).fillna(df['State Code'])

# %%
df['State Code'].value_counts()
# Out:
# Texas             254
# Georgia           159
# Virginia          133
# Kentucky          120
# Missouri          115
# Kansas            105
# Illinois          102
# North Carolina    100
# Iowa               99
# Tennessee          95
# Nebraska           93
# Indiana            92
# Ohio               88
# Minnesota          87
# Michigan           83
# Mississippi        82
# Oklahoma           77
# Arkansas           75
# Wisconsin          72
# Pennsylvania       67
# Florida            67
# Alabama            67
# South Dakota       66
# Colorado           64
# Louisiana          64
# New York           62
# California         58
# Montana            56
# West Virginia      55
# North Dakota       53
# South Carolina     46
# Idaho              44
# Washington         39
# Oregon             36
# New Mexico         33
# Utah               29
# Maryland           24
# Wyoming            23
# New Jersey         21
# Nevada             17
# Maine              16
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3113 entries, 0 to 3112
# Data columns (total 39 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   State Code                                  3113 non-null   object
#  1   County Name                                 3113 non-null   object
#  2    County Population                          3112 non-null   object
#  3   Clinton or Trump State                      3113 non-null   object
#  4    Clinton                                    3113 non-null   object
#  5    Trump                                      3113 non-null   object
#  6    Total                                      3113 non-null   object
#  7   % Clinton                                   3113 non-null   object
#  8   % Trump                                     3113 non-null   object
#  9    Vote Difference C-T                        3113 non-null   object
# ...

# %%
from pickle import load

# %%
df_race = load(open('df_race.pkl', 'rb'))

# %%
df['State Code'].value_counts().count()
# Out:
# 51

# %%
df_race['State'].value_counts().count()
# Out:
# 52

# %%
DC = (df_race.loc[df_race['State'].str.contains('District of Columbia', case=False)]).index

# %%
DC
# Out:
# Int64Index([322], dtype='int64')

# %%
DC = df_race.drop(DC)

# %%
df_race.State.str.contains('District of Columbia').value_counts()
# Out:
# False    3220
# True        1
# Name: State, dtype: int64

# %%
df_race.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3221 entries, 2 to 3222
# Data columns (total 12 columns):
#  #   Column                                                                       Non-Null Count  Dtype
# ---  ------                                                                       --------------  -----
#  0   id                                                                           3221 non-null   object
#  1   Total                                                                        3221 non-null   float64
#  2   TotalPopulation of one race                                                  3221 non-null   float64
#  3   TotalPopulation of one raceWhite alone                                       3221 non-null   float64
#  4   TotalPopulation of one raceBlack or African American alone                   3221 non-null   float64
#  5   TotalPopulation of one raceAmerican Indian and Alaska Native alone           3221 non-null   float64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3113 entries, 0 to 3112
# Data columns (total 39 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   State Code                                  3113 non-null   object
#  1   County Name                                 3113 non-null   object
#  2    County Population                          3112 non-null   object
#  3   Clinton or Trump State                      3113 non-null   object
#  4    Clinton                                    3113 non-null   object
#  5    Trump                                      3113 non-null   object
#  6    Total                                      3113 non-null   object
#  7   % Clinton                                   3113 non-null   object
#  8   % Trump                                     3113 non-null   object
#  9    Vote Difference C-T                        3113 non-null   object
# ...

# %%
# df_race['County'] = df_race['County'].str.rstrip('County')
df['County Name'] = df['County Name'].str.rstrip('County')

# %%
df['County Name'].value_counts()
# Out:
# Washington      30
# Jefferson       25
# Franklin        24
# Lincoln         23
# Jackson         23
#                 ..
# Crosby           1
# Calaveras        1
# Goodhue          1
# Buena Vista      1
# Corson           1
# Name: County Name, Length: 1848, dtype: int64

# %%
# df_race.where(df['County Name'] is in df_race['County'].values).notna()
df['County Name'].isin(df_race['County']).value_counts()
# Out:
# True     3110
# False       3
# Name: County Name, dtype: int64

# %%
# df_common = df1.loc[df1['set1'].isin(df2['set2'])]

missing = df.loc[~df['County Name'].isin(df_race['County'])]

# %%
missing
# Out:
#         State Code      County Name  County Population   \
# 67          Alaska           Alaska            738,432
# 1113     Louisiana  La Salle Parish             14,974
# 2388  South Dakota          Oglala                  NaN
#
#      Clinton or Trump State  Clinton      Trump      Total  % Clinton % Trump  \
# 67                    Trump   93,007    130,415    246,588     37.72%  52.89%
# 1113                  Trump      605      5,835      6,568      9.21%  88.84%
# 2388                  Trump    2,504        241      2,896     86.46%   8.32%
#
#       Vote Difference C-T   ... County FIPS Code CBSA Code CSA Code  \
# 67                (37,408)  ...              NaN       NaN      NaN
# 1113               (5,230)  ...             59.0       NaN      NaN
# 2388                2,263   ...            113.0       NaN      NaN
#
#      CBSA Title CBSA Population Metropolitan/Micropolitan Statistical Area  \
# ...

# %%
pd.set_option("max_rows", None)

# %% [markdown]
# Why isn't this working??

# %%
# (to_replace={'a': None}, value=None, method=None):

# %%
df = df.replace('Oglala', 'Oglala Lakota', regex = True)

# %%
(df.loc[df['County Name'].str.contains('Oglala', case=False)])
# Out:
#         State Code     County Name  County Population  Clinton or Trump State  \
# 2388  South Dakota  Oglala Lakota                  NaN                  Trump
#
#       Clinton   Trump    Total  % Clinton % Trump  Vote Difference C-T   ...  \
# 2388    2,504     241    2,896     86.46%   8.32%                2,263   ...
#
#      County FIPS Code CBSA Code CSA Code CBSA Title CBSA Population  \
# 2388            113.0       NaN      NaN        NaN             NaN
#
#      Metropolitan/Micropolitan Statistical Area CSA Title  \
# 2388                                        NaN       NaN
#
#      Metropolitan Division Title Metropolitan Division Code  \
# 2388                         NaN                        NaN
#
#                  Central/Outlying County
# 2388  Not Metro or Micro, Presumed Rural
#
# [1 rows x 39 columns]

# %%
df.head()
# Out:
#   State Code County Name  County Population  Clinton or Trump State  Clinton   \
# 0    Alabama    Autauga              55,347                   Trump    5,908
# 1    Alabama    Baldwin             203,709                   Trump   18,409
# 2    Alabama    Barbour              26,489                   Trump    4,848
# 3    Alabama       Bibb              22,583                   Trump    1,874
# 4    Alabama     Blount              57,673                   Trump    2,150
#
#      Trump     Total  % Clinton % Trump  Vote Difference C-T   ...  \
# 0   18,110    24,661     23.96%  73.44%              (12,202)  ...
# 1   72,780    94,090     19.57%  77.35%              (54,371)  ...
# 2    5,431    10,390     46.66%  52.27%                 (583)  ...
# 3    6,733     8,748     21.42%  76.97%               (4,859)  ...
# 4   22,808    25,384      8.47%  89.85%              (20,658)  ...
#
#   County FIPS Code CBSA Code CSA Code                 CBSA Title  \
# ...

# %%
missing = df.loc[~df['County Name'].isin(df_race['County'])]
missing
# Out:
#      State Code      County Name  County Population  Clinton or Trump State  \
# 67       Alaska           Alaska            738,432                   Trump
# 1113  Louisiana  La Salle Parish             14,974                   Trump
#
#       Clinton      Trump      Total  % Clinton % Trump  Vote Difference C-T   \
# 67     93,007    130,415    246,588     37.72%  52.89%              (37,408)
# 1113      605      5,835      6,568      9.21%  88.84%               (5,230)
#
#       ... County FIPS Code CBSA Code CSA Code CBSA Title CBSA Population  \
# 67    ...              NaN       NaN      NaN        NaN             NaN
# 1113  ...             59.0       NaN      NaN        NaN             NaN
#
#      Metropolitan/Micropolitan Statistical Area CSA Title  \
# 67                                          NaN       NaN
# 1113                                        NaN       NaN
#
#      Metropolitan Division Title Metropolitan Division Code  \
# ...

# %%
(df.loc[df['State Code'].str.contains('Alaska', case=False)])
# Out:
#    State Code County Name  County Population  Clinton or Trump State  \
# 67     Alaska      Alaska            738,432                   Trump
#
#     Clinton      Trump      Total  % Clinton % Trump  Vote Difference C-T   \
# 67   93,007    130,415    246,588     37.72%  52.89%              (37,408)
#
#     ... County FIPS Code CBSA Code CSA Code CBSA Title CBSA Population  \
# 67  ...              NaN       NaN      NaN        NaN             NaN
#
#    Metropolitan/Micropolitan Statistical Area CSA Title  \
# 67                                        NaN       NaN
#
#    Metropolitan Division Title Metropolitan Division Code  \
# 67                         NaN                        NaN
#
#    Central/Outlying County
# 67                Z-Alaska
#
# [1 rows x 39 columns]
