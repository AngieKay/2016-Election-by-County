# %%
pip list
# Out:
# Package                           Version
# --------------------------------- -------------------
# absl-py                           0.10.0
# affine                            2.3.0
# aiohttp                           3.6.3
# altair                            4.1.0
# argon2-cffi                       20.1.0
# arviz                             0.10.0
# astunparse                        1.6.3
# async-generator                   1.10
# async-timeout                     3.0.1
# attrs                             20.2.0
# autopep8                          1.5.7
# backcall                          0.2.0
# backports.functools-lru-cache     1.6.1
# beautifulsoup4                    4.9.3
# bleach                            3.2.1
# blosc                             1.10.2
# boto                              2.49.0
# boto3                             1.15.16
# botocore                          1.18.16
# branca                            0.4.1
# brotlipy                          0.7.0
# ...
